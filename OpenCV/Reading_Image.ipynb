# %%
pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 1.7 MB/s eta 0:00:0000:0100:01m
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
#read an image

img = cv2.imread('F1AE69F0-BE04-466D-8288-363EF654D04E_4_5005_c.jpeg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
#when we read an image through oopen cv it treats as BGR and not RGB, so wherever theres red in orig image theres blue

# %%
newImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(newImg)

# %%
# 255 is white
# 0 is black

# %%
# Using open cv to display an image

# %%
img = cv2.imread('F1AE69F0-BE04-466D-8288-363EF654D04E_4_5005_c.jpeg')
gray = cv2.imread('F1AE69F0-BE04-466D-8288-363EF654D04E_4_5005_c.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
# to be run in the image terminal

cv2.imshow('Muaz', img) #Dont really need to convert to RGB to show using cv2
cv2.waitKey(0) # 0 means wait for infinite time before closing the window
cv2.destroyAllWindows()

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 cv2.imshow(gray)
#
# error: OpenCV(4.11.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)
