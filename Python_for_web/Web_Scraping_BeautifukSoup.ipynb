# %%
import bs4
import requests

# %%
url = 'https://www.snapdeal.com/search'

# %%
params = {
            'keyword' : 'mobile'
}

# %%
response = requests.get(url, params = params) # This will give me an entire html page

# %%
# Beautiful Soup is a html parser so all this need is html data, in this case response content
soup = bs4.BeautifulSoup(response.content)

# %%
article_element = soup.findAll('article')

# %%
article_element[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 article_element[0]
#
# IndexError: list index out of range

# %%
article.img.attributes['src']
# Out:
# b'<!DOCTYPE html>\n<html class="no-js" dir="ltr" lang="en-US">\n<head>\n  <meta charset="utf-8">\n  <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n  <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n  <meta name="viewport" content="width=device-width,initial-scale=1.0" />\n  <title>\xe2\x80\x9cYour self-worth is determined by you. You | The Foundation for a Better Life</title>\n<meta name="description" content="An inspirational quote by Beyonc\xc3\xa9 Knowles-Carter about the value of Believe In Yourself: \xe2\x80\x9cYour self-worth is determined by you. You don\xe2\x80\x99t have to depend on">\n<meta name="keywords" content="pass, it, on, passiton, values, kindness">\n<meta name="twitter:site_name" content="The Foundation for a Better Life">\n<meta name="twitter:site" content="@passiton_values">\n<meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:description" content="An inspirational quote by Beyonc\xc3\xa9 Knowles-Carter ab
# ...

# %%
 with open('inspiration.jpg', 'wb') as file:
     img_url = article.img.sttributes['src']
     file.wrie(requests.get(img_url).content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 with open('inspiration.jpg', 'wb') as file:
# ----> 2     img_url = article.img_url
#       3     file.wrie(requests.get(img_url).content)
#
# NameError: name 'article' is not defined

# %%
for i, article in enumerate(article_element):
    with open('inspiration{}.jpg'.format(i), 'wb') as file:
        img_url = article.img.attrs['src']
        response = requests.get(img_url)

        file.write(response.content)

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.snapdeal.com/search'
params = {
    'keyword': 'mobile'
}
headers = {
    'User-Agent': 'Mozilla/5.0'
}

response = requests.get(url, params=params, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# Try to find product containers
products = soup.find_all('div', class_='product-tuple-description')
print(f"Found {len(products)} products.")

for p in products[:5]:  # Display first 5
    print(p.get_text(strip=True))
# Out:
# Found 20 products.
# Shop To Shop Bluetooth Selfie Flash Light ( Black )Rs. 999Rs.  21379% Off(123)Color
# UNICAL Impact Resistant Mobile Stickers for Smartphones and Tablets ( Black )Rs. 499Rs.  10978% Off(594)Color
# HUG PUPPY Bluetooth Selfie Stick ( Black )Rs. 999Rs.  18382% Off(85)Color
# HUG PUPPY Bluetooth Selfie Stick ( Black )Rs. 999Rs.  18382% Off(119)Color
# Tecsox Foldable Connectors for Smartphones ( Black )Rs. 1,999Rs.  17591% Off(134)Color
